# %%
"/mnt/SSD5/yipeng/VAE/data/ucla/Pt1_AR/Pt1_AR/label.csv"
# I want to remove the second folder which is Pt1_AR 
import os
import shutil
path = "/mnt/SSD5/yipeng/VAE/data_old/detroit/"
for pt_names in os.listdir(path):
    # remove the /mnt/SSD5/yipeng/VAE/data/ucla/{pt}/{pt}
    folder_to_remove = path + pt_names + "/" + pt_names
    shutil.rmtree(folder_to_remove)
    print(folder_to_remove)
# Out:
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M10011/M10011
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M10036/M10036
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M14016/M14016
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M07009/M07009
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M12036/M12036
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M10019/M10019
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M15022/M15022
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M12017/M12017
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M07015/M07015
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M13032/M13032
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M11026/M11026
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M15019/M15019
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M10014/M10014
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M08032/M08032
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M08005/M08005
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M13029/M13029
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M13012/M13012
# /mnt/SSD5/yipeng/VAE/data_old/detroit/M10007/M10007
# ...
